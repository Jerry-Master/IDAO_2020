# %% [markdown]
# # Checkpoints Comparation with Train

# %% [markdown]
# ## 1. Llibraries i funció comparació

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
def score(satellite_predicted_values, satellite_true_values): 
    # the division, addition and subtraction are pointwise 
    smape =  np.mean(np.abs((satellite_predicted_values - satellite_true_values) 
        / (np.abs(satellite_predicted_values) + np.abs(satellite_true_values))))
    return 100 * (1 - smape)

# %% [markdown]
# ## 2. Importació del train i les prediccions del train

# %%
raw = pd.read_csv("train.csv")[['x_sim', 'y_sim', 'z_sim', 'Vx_sim', 'Vy_sim', 'Vz_sim']].values
reals = pd.read_csv("train.csv")[['x', 'y', 'z', 'Vx', 'Vy', 'Vz']].values
improveds = pd.read_csv('../Track 1/Especial/corrected2.csv')[['x', 'y', 'z', 'Vx', 'Vy', 'Vz']].values

# %%
if (len(improveds) != 649912):
    print("Warning: La mida del document hauria de ser 64991")

# %% [markdown]
# ## 3. Puntuacions generals

# %%
print("La puntuació del default  és:   " + str(score(raw, reals)))
print("La puntuació del improved és:   " + str(score(improveds, reals)))
# Out:
# La puntuació del default  és:   81.27485106384843
# La puntuació del improved és:   90.7878627142237

# %% [markdown]
# ## 4. Puntuacions particulars

# %%
raw = pd.read_csv("train.csv")[['sat_id','x_sim', 'y_sim', 'z_sim', 'Vx_sim', 'Vy_sim', 'Vz_sim']]
real = pd.read_csv("train.csv")[['sat_id','x', 'y', 'z', 'Vx', 'Vy', 'Vz']]
improved = pd.read_csv('../Track 1/Especial/corrected2.csv')[['sat_id','x', 'y', 'z', 'Vx', 'Vy', 'Vz']]

# %%
tot = 0
for i in range(0,600):
    raw_i = raw[raw['sat_id']==i].values
    real_i = real[real['sat_id']==i].values
    improved_i = improved[improved['sat_id']==i].values
    
    print("El satèl·lit: " + str(i) + " té puntuació del default  és: " + str(score(raw_i[:,1:7], real_i[:,1:7])))
    print("El satèl·lit: " + str(i) + " té puntuació del improved és: " + str(score(improved_i[:,1:7], real_i[:,1:7])))
    print("----------")
# Out:
# El satèl·lit: 0 té puntuació del default  és: 78.64960424795602
# El satèl·lit: 0 té puntuació del improved és: 98.26922279617187
# ----------
# El satèl·lit: 1 té puntuació del default  és: 86.35781797479511
# El satèl·lit: 1 té puntuació del improved és: 90.31036097660964
# ----------
# El satèl·lit: 2 té puntuació del default  és: 84.31732138046632
# El satèl·lit: 2 té puntuació del improved és: 93.59186868137655
# ----------
# El satèl·lit: 3 té puntuació del default  és: 85.77711192479482
# El satèl·lit: 3 té puntuació del improved és: 92.0058387994628
# ----------
# El satèl·lit: 4 té puntuació del default  és: 69.01223534453582
# El satèl·lit: 4 té puntuació del improved és: 97.84777296106903
# ----------
# El satèl·lit: 5 té puntuació del default  és: 83.12261141276323
# El satèl·lit: 5 té puntuació del improved és: 97.64518202714095
# ----------
# El satèl·lit: 6 té puntuació del default  és: 71.59408545863444
# ...

# %%
tot = 0
scores = [[],[]]
good_scores = [[],[]]
bad_scores = [[],[]]

for i in range(0,600):
    real_i = real[real['sat_id']==i].values
    improved_i = improved[improved['sat_id']==i].values
    
    s = score(improved_i[:,1:7], real_i[:,1:7])
        
    if (s < 60):
        bad_scores[0].append(i)
        bad_scores[1].append(s)
        tot += 1
        print("El satèl·lit: " + str(i) + " té puntuació del improved és: " + str(score(improved_i[:,1:7], real_i[:,1:7])))
        print("----------")
        
    else:
        good_scores[0].append(i)
        good_scores[1].append(s)
    
    scores[0].append(i)
    scores[1].append(s)
# Out:
# El satèl·lit: 473 té puntuació del improved és: 55.20061846130957
# ----------
# El satèl·lit: 523 té puntuació del improved és: 52.58351009442801
# ----------
# El satèl·lit: 587 té puntuació del improved és: 52.540128761615556
# ----------

# %% [markdown]
# ## 5. Gràfics

# %%
plt.figure(1)
plt.scatter(good_scores[0], good_scores[1], color = 'b')
plt.scatter(bad_scores[0], bad_scores[1], color = 'r')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
N = 600
theta = scores[1]
colors = (np.array(theta)/100)**20
plt.figure(2)
plt.plot([0, 600],[score(improveds, reals), score(improveds, reals)], 'r')
plt.scatter(scores[0], scores[1], c = colors)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## 6. Descriptiva puntual

# %%
id = 249

real_id = real[real['sat_id']==id]
improved_id = improved[improved['sat_id']==id]

a = 0
b = 1837

plt.figure(id*10)
plt.plot(range(0,len(improved_id['x'][a:b])), improved_id['x'][a:b])
plt.plot(range(0,len(real_id['x'][a:b])), real_id['x'][a:b], c='r')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
a = 0
b = 1837

for id in bad_scores[0]:
    real_id = real[real['sat_id']==id]
    improved_id = improved[improved['sat_id']==id]

    plt.figure(id)
    plt.scatter(range(0,len(improved_id['x'][a:b])), improved_id['x'][a:b])
    plt.plot(range(0,len(real_id['x'][a:b])), real_id['x'][a:b], c='r')
    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
bad_scores[0]
# Out:
# [37, 249, 372, 514, 523, 587]
